# %% [markdown]
# # Beau Home House Prices Prediction

# %% [markdown]
# **Exploratory Data Analysis**
#
# To start exploring the data I will first start off with importing the necessary libraries I will be needing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import StrMethodFormatter, NullFormatter
# %matplotlib inline

import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn import svm
from sklearn.metrics import r2_score

import xgboost as xgb
from xgboost import XGBRegressor

import warnings
warnings.filterwarnings(action = 'ignore', category = FutureWarning)

# %% [markdown]
# **House Data Info**
#
# The dataframe that I will be working with is a houses data set, the first step is that I will read into the csv file

# %%
# Read the dataset into a data table using Pandas and show the first 5 rows
house_df = pd.read_csv('Data/house_data_set.csv')
house_df.head()
# Out:
#    year_built  stories  num_bedrooms  full_bathrooms  half_bathrooms  \
# 0        1978        1             4               1               1
# 1        1958        1             3               1               1
# 2        2002        1             3               2               0
# 3        2004        1             4               2               0
# 4        2006        1             4               2               0
#
#    livable_sqft  total_sqft garage_type  garage_sqft  carport_sqft  \
# 0          1689        1859    attached          508             0
# 1          1984        2002    attached          462             0
# 2          1581        1578        none            0           625
# 3          1829        2277    attached          479             0
# 4          1580        1749    attached          430             0
#
#    has_fireplace  has_pool  has_central_heating  has_central_cooling  \
# 0           True     False                 True                 True
# 1           True     False                 True                 True
# 2          False     False                 True                 True
# 3           True     False                 True                 True
# 4           True     False                 True                 True
#
#    house_number       street_name  unit_number                city  zip_code  \
# 0         42670    Lopez Crossing          NaN            Hallfort     10907
# 1          5194      Gardner Park          NaN            Hallfort     10907
# 2          4366   Harding Islands          NaN  Lake Christinaport     11203
# 3          3302  Michelle Highway          NaN  Lake Christinaport     11203
# 4           582        Jacob Cape          NaN  Lake Christinaport     11203
#
#    sale_price
# 0    270897.0
# 1    302404.0
# 2   2519996.0
# 3    197193.0
# 4    207897.0

# %% [markdown]
# I will get additional information on the dataframe to see if it has any null values and the types of data

# %%
#Basic info on data
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42703 entries, 0 to 42702
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year_built           42703 non-null  int64
#  1   stories              42703 non-null  int64
#  2   num_bedrooms         42703 non-null  int64
#  3   full_bathrooms       42703 non-null  int64
#  4   half_bathrooms       42703 non-null  int64
#  5   livable_sqft         42703 non-null  int64
#  6   total_sqft           42703 non-null  int64
#  7   garage_type          42703 non-null  object
#  8   garage_sqft          42703 non-null  int64
#  9   carport_sqft         42703 non-null  int64
#  10  has_fireplace        42703 non-null  bool
#  11  has_pool             42703 non-null  bool
#  12  has_central_heating  42703 non-null  bool
#  13  has_central_cooling  42703 non-null  bool
#  14  house_number         42703 non-null  int64
#  15  street_name          42703 non-null  object
#  16  unit_number          3088 non-null   float64
#  17  city                 42703 non-null  object
#  18  zip_code             42703 non-null  int64
#  19  sale_price           42703 non-null  float64
# dtypes: bool(4), float64(2), int64(11), object(3)
# memory usage: 5.4+ MB

# %% [markdown]
# This data set has 19 house features (not counting sale price) and 42703 data entries, I will be using those features in my model later on to help predict the house sale price.

# %%
house_df.describe()
# Out:
#          year_built       stories  num_bedrooms  full_bathrooms  \
# count  42703.000000  42703.000000  42703.000000    42703.000000
# mean    1990.993209      1.365759      3.209283        1.923659
# std       19.199987      0.513602      1.043396        0.759699
# min     1852.000000      0.000000      0.000000        0.000000
# 25%     1980.000000      1.000000      3.000000        1.000000
# 50%     1994.000000      1.000000      3.000000        2.000000
# 75%     2005.000000      2.000000      4.000000        2.000000
# max     2017.000000      4.000000     31.000000        8.000000
#
#        half_bathrooms  livable_sqft    total_sqft   garage_sqft  carport_sqft  \
# count    42703.000000  42703.000000  42703.000000  42703.000000  42703.000000
# mean         0.527153   1987.758986   2127.155446    455.849800     41.656324
# std          0.499268    846.766270    922.807342    243.453463    168.715867
# min          0.000000     -3.000000      5.000000     -4.000000      0.000000
# 25%          0.000000   1380.000000   1466.000000    412.000000      0.000000
# 50%          1.000000   1808.000000   1937.000000    464.000000      0.000000
# 75%          1.000000   2486.000000   2640.000000    606.000000      0.000000
# max          1.000000  12406.000000  15449.000000   8318.000000   9200.000000
#
#        house_number  unit_number      zip_code    sale_price
# count  42703.000000  3088.000000  42703.000000  4.270300e+04
# mean   18211.767347  2027.395402  11030.991476  4.135071e+05
# std    27457.109993  1141.383770    573.576228  3.185497e+05
# min        0.000000     3.000000  10004.000000  6.260000e+02
# 25%      674.000000  1063.000000  10537.000000  2.708990e+05
# 50%     4530.000000  2033.000000  11071.000000  3.780010e+05
# 75%    24844.500000  2921.000000  11510.000000  4.976970e+05
# max    99971.000000  3998.000000  11989.000000  2.104200e+07

# %%
#I will transpose the data so we can better see it  displayed
house_df.describe().transpose()
# Out:
#                   count           mean            std      min       25%  \
# year_built      42703.0    1990.993209      19.199987   1852.0    1980.0
# stories         42703.0       1.365759       0.513602      0.0       1.0
# num_bedrooms    42703.0       3.209283       1.043396      0.0       3.0
# full_bathrooms  42703.0       1.923659       0.759699      0.0       1.0
# half_bathrooms  42703.0       0.527153       0.499268      0.0       0.0
# livable_sqft    42703.0    1987.758986     846.766270     -3.0    1380.0
# total_sqft      42703.0    2127.155446     922.807342      5.0    1466.0
# garage_sqft     42703.0     455.849800     243.453463     -4.0     412.0
# carport_sqft    42703.0      41.656324     168.715867      0.0       0.0
# house_number    42703.0   18211.767347   27457.109993      0.0     674.0
# unit_number      3088.0    2027.395402    1141.383770      3.0    1063.0
# zip_code        42703.0   11030.991476     573.576228  10004.0   10537.0
# sale_price      42703.0  413507.124647  318549.650655    626.0  270899.0
#
#                      50%       75%         max
# year_built        1994.0    2005.0      2017.0
# stories              1.0       2.0         4.0
# num_bedrooms         3.0       4.0        31.0
# full_bathrooms       2.0       2.0         8.0
# half_bathrooms       1.0       1.0         1.0
# livable_sqft      1808.0    2486.0     12406.0
# total_sqft        1937.0    2640.0     15449.0
# garage_sqft        464.0     606.0      8318.0
# carport_sqft         0.0       0.0      9200.0
# house_number      4530.0   24844.5     99971.0
# unit_number       2033.0    2921.0      3998.0
# zip_code         11071.0   11510.0     11989.0
# sale_price      378001.0  497697.0  21041998.0

# %%
house_df.corr()
# Out:
#                      year_built   stories  num_bedrooms  full_bathrooms  \
# year_built             1.000000  0.340048      0.354184        0.507460
# stories                0.340048  1.000000      0.411178        0.386661
# num_bedrooms           0.354184  0.411178      1.000000        0.547654
# full_bathrooms         0.507460  0.386661      0.547654        1.000000
# half_bathrooms         0.018290  0.188167      0.090575       -0.326024
# livable_sqft           0.501600  0.402780      0.646047        0.718242
# total_sqft             0.441766  0.345969      0.599964        0.683580
# garage_sqft            0.418244  0.263845      0.479839        0.419770
# carport_sqft          -0.183255 -0.164134     -0.224600       -0.071632
# has_fireplace          0.133737  0.177420      0.310697        0.234325
# has_pool              -0.023889 -0.027474      0.156539        0.169734
# has_central_heating    0.535366  0.145494      0.179828        0.273856
# has_central_cooling    0.566484  0.176515      0.190266        0.310613
# house_number           0.005649 -0.008927     -0.002300        0.006440
# unit_number           -0.012783  0.035306      0.029626       -0.015574
# zip_code               0.034625 -0.020229     -0.068778        0.012807
# sale_price             0.227948  0.130693      0.316768        0.429947
#
#                      half_bathrooms  livable_sqft  total_sqft  garage_sqft  \
# year_built                 0.018290      0.501600    0.441766     0.418244
# stories                    0.188167      0.402780    0.345969     0.263845
# num_bedrooms               0.090575      0.646047    0.599964     0.479839
# full_bathrooms            -0.326024      0.718242    0.683580     0.419770
# half_bathrooms             1.000000      0.103696    0.108050     0.154152
# livable_sqft               0.103696      1.000000    0.975450     0.597781
# total_sqft                 0.108050      0.975450    1.000000     0.586785
# garage_sqft                0.154152      0.597781    0.586785     1.000000
# carport_sqft              -0.155806     -0.179945   -0.180651    -0.406683
# has_fireplace              0.110508      0.321354    0.314783     0.415696
# has_pool                   0.046666      0.261967    0.290305     0.202434
# has_central_heating        0.082710      0.257247    0.228405     0.240686
# has_central_cooling        0.060697      0.294371    0.266848     0.284199
# house_number              -0.006542      0.001166   -0.000965    -0.005734
# unit_number                0.042163      0.019502    0.017894     0.041400
# zip_code                  -0.022586     -0.016870   -0.006054    -0.046963
# sale_price                 0.094280      0.627508    0.660714     0.448928
#
#                      carport_sqft  has_fireplace  has_pool  \
# year_built              -0.183255       0.133737 -0.023889
# stories                 -0.164134       0.177420 -0.027474
# num_bedrooms            -0.224600       0.310697  0.156539
# full_bathrooms          -0.071632       0.234325  0.169734
# half_bathrooms          -0.155806       0.110508  0.046666
# livable_sqft            -0.179945       0.321354  0.261967
# total_sqft              -0.180651       0.314783  0.290305
# garage_sqft             -0.406683       0.415696  0.202434
# carport_sqft             1.000000      -0.268507 -0.078099
# has_fireplace           -0.268507       1.000000  0.229999
# has_pool                -0.078099       0.229999  1.000000
# has_central_heating     -0.008206       0.177342  0.069128
# has_central_cooling     -0.057609       0.190158  0.070788
# house_number             0.001885      -0.008864  0.009759
# unit_number             -0.025643       0.003104 -0.007202
# zip_code                 0.074363      -0.048129 -0.018679
# sale_price              -0.197384       0.275813  0.355073
#
#                      has_central_heating  has_central_cooling  house_number  \
# year_built                      0.535366             0.566484      0.005649
# stories                         0.145494             0.176515     -0.008927
# num_bedrooms                    0.179828             0.190266     -0.002300
# full_bathrooms                  0.273856             0.310613      0.006440
# half_bathrooms                  0.082710             0.060697     -0.006542
# livable_sqft                    0.257247             0.294371      0.001166
# total_sqft                      0.228405             0.266848     -0.000965
# garage_sqft                     0.240686             0.284199     -0.005734
# carport_sqft                   -0.008206            -0.057609      0.001885
# has_fireplace                   0.177342             0.190158     -0.008864
# has_pool                        0.069128             0.070788      0.009759
# has_central_heating             1.000000             0.764562      0.004885
# has_central_cooling             0.764562             1.000000     -0.004199
# house_number                    0.004885            -0.004199      1.000000
# unit_number                     0.007746             0.042411     -0.038578
# zip_code                        0.031713             0.061431     -0.008179
# sale_price                      0.115658             0.142121      0.001265
#
#                      unit_number  zip_code  sale_price
# year_built             -0.012783  0.034625    0.227948
# stories                 0.035306 -0.020229    0.130693
# num_bedrooms            0.029626 -0.068778    0.316768
# full_bathrooms         -0.015574  0.012807    0.429947
# half_bathrooms          0.042163 -0.022586    0.094280
# livable_sqft            0.019502 -0.016870    0.627508
# total_sqft              0.017894 -0.006054    0.660714
# garage_sqft             0.041400 -0.046963    0.448928
# carport_sqft           -0.025643  0.074363   -0.197384
# has_fireplace           0.003104 -0.048129    0.275813
# has_pool               -0.007202 -0.018679    0.355073
# has_central_heating     0.007746  0.031713    0.115658
# has_central_cooling     0.042411  0.061431    0.142121
# house_number           -0.038578 -0.008179    0.001265
# unit_number             1.000000 -0.006868    0.035429
# zip_code               -0.006868  1.000000   -0.017199
# sale_price              0.035429 -0.017199    1.000000

# %%
# Plotting the heatmap of correlation between features
plt.figure(figsize=(12,12))
sns.heatmap(house_df.corr(), cbar=True, square= True, fmt='.1f', annot=True, annot_kws={'size':10}, cmap='Greens')
# Out:
# <AxesSubplot: >

# %%
#total_sqft had the highest correlation, so I wanted to plot it
house_df.plot.scatter(x='total_sqft',y='sale_price');

# format the y label 1e7
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

plt.show()
# Out:
# C:\Users\dtaher\Anaconda3\envs\learn-env\lib\site-packages\pandas\plotting\_matplotlib\core.py:1010: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# C:\Users\dtaher\AppData\Local\Temp\ipykernel_15056\1459407522.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# %% [markdown]
# **Data Cleaning & Preparation**
#
# In this section, I will start by cleaning the house dataframe before drawing any conclusions. It will help inspect the data better and get a more accurate general understanding of the data at hand.
#
# **Step 1:** check  all columns in data frame

# %%
house_df.columns
# Out:
# Index(['year_built', 'stories', 'num_bedrooms', 'full_bathrooms',
#        'half_bathrooms', 'livable_sqft', 'total_sqft', 'garage_type',
#        'garage_sqft', 'carport_sqft', 'has_fireplace', 'has_pool',
#        'has_central_heating', 'has_central_cooling', 'house_number',
#        'street_name', 'unit_number', 'city', 'zip_code', 'sale_price'],
#       dtype='object')

# %% [markdown]
# Now that I have seen all the columns and what features the dataframe entails, I want to select only the features that will be relative and useful to my model, in this next section I will be preparing the desired features.

# %% [markdown]
# **Step 2:** Remove unwanted columns
#
# There are some features that will not be useful in my model therefore, I will delete the columns that I won't need.
#
# The house number isn't going to be useful to include in the model since it's not likely that anyone buys a house because the street number assigned to it, it's just a random number. So I will drop this field from the model.
# The same will go for unit number. As for street name, city, and zip code columns, the location of a house has a big influence on the value so we need to include at least some of this information in the model. However, these columns provide duplicate information. For example, if we know the zip code of a house, we already know what city it's in, so I don't need to include both city and zip code in my model. I will also delete street name since.

# %%
#There are 4 columns that I will remove since i will not included it in my model and has 0 correlation with our target
house_df.drop(['house_number', 'street_name', 'unit_number','zip_code'], axis = 1, inplace=True)
house_df.head()
# Out:
#    year_built  stories  num_bedrooms  full_bathrooms  half_bathrooms  \
# 0        1978        1             4               1               1
# 1        1958        1             3               1               1
# 2        2002        1             3               2               0
# 3        2004        1             4               2               0
# 4        2006        1             4               2               0
#
#    livable_sqft  total_sqft garage_type  garage_sqft  carport_sqft  \
# 0          1689        1859    attached          508             0
# 1          1984        2002    attached          462             0
# 2          1581        1578        none            0           625
# 3          1829        2277    attached          479             0
# 4          1580        1749    attached          430             0
#
#    has_fireplace  has_pool  has_central_heating  has_central_cooling  \
# 0           True     False                 True                 True
# 1           True     False                 True                 True
# 2          False     False                 True                 True
# 3           True     False                 True                 True
# 4           True     False                 True                 True
#
#                  city  sale_price
# 0            Hallfort    270897.0
# 1            Hallfort    302404.0
# 2  Lake Christinaport   2519996.0
# 3  Lake Christinaport    197193.0
# 4  Lake Christinaport    207897.0

# %% [markdown]
# **Step 3:** Check for any duplicates or null values

# %%
house_df.duplicated().value_counts()
# Out:
# False    42703
# dtype: int64

# %% [markdown]
# no duplicates, so we're good to proceed

# %%
house_df.isnull().sum()
# Out:
# year_built             0
# stories                0
# num_bedrooms           0
# full_bathrooms         0
# half_bathrooms         0
# livable_sqft           0
# total_sqft             0
# garage_type            0
# garage_sqft            0
# carport_sqft           0
# has_fireplace          0
# has_pool               0
# has_central_heating    0
# has_central_cooling    0
# city                   0
# sale_price             0
# dtype: int64

# %% [markdown]
# no null values, we're good to proceed

# %%
#sorting by sale price to see the highest and lowest
house_df.sort_values("sale_price", ascending = False)
# Out:
#        year_built  stories  num_bedrooms  full_bathrooms  half_bathrooms  \
# 14910        1974        1             2               2               0
# 15714        2014        2             5               5               1
# 32270        2013        2             5               4               1
# 7338         1983        1             2               2               0
# 20997        2002        1             5               4               1
# ...           ...      ...           ...             ...             ...
# 25261        1966        1             1               1               0
# 11844        1971        1             1               1               0
# 22447        1963        1             1               1               0
# 35927        1963        1             2               2               0
# 3672         1967        1             2               1               0
#
#        livable_sqft  total_sqft garage_type  garage_sqft  carport_sqft  \
# 14910          1446        1438        none            0           298
# 15714          9806       12448    attached         1502             0
# 32270          7953        8934    attached         1344             0
# 7338           1438        1644        none            0           716
# 20997          8309        9340    attached          885             0
# ...             ...         ...         ...          ...           ...
# 25261           475         469        none            0           378
# 11844           794         799        none            0           349
# 22447           671         668        none            0           296
# 35927           902         903        none            0           298
# 3672            633         637        none            0           397
#
#        has_fireplace  has_pool  has_central_heating  has_central_cooling  \
# 14910          False     False                 True                False
# 15714           True      True                 True                 True
# 32270           True     False                 True                 True
# 7338           False     False                 True                 True
# 20997           True      True                 True                 True
# ...              ...       ...                  ...                  ...
# 25261          False     False                 True                False
# 11844          False     False                 True                 True
# 22447          False     False                 True                False
# 35927          False     False                 True                False
# 3672           False     False                 True                False
#
#                    city  sale_price
# 14910          Coletown  21041998.0
# 15714        Lewishaven  10836004.0
# 32270        Lewishaven   9141303.0
# 7338       Lake Carolyn   7811999.0
# 20997        Lewishaven   7811996.0
# ...                 ...         ...
# 25261  East Janiceville       626.0
# 11844      Jeffreyhaven       626.0
# 22447      Jeffreyhaven       626.0
# 35927      Jeffreyhaven       626.0
# 3672          Scottberg       626.0
#
# [42703 rows x 16 columns]

# %% [markdown]
# **Step 4:** Check if the features columns need any preparation
#
# The columns with true and false values will be fine to use in my model since they'll be treated as one or zero automatically, so no extra work is needed to prepare it.

# %% [markdown]
# **Numerical Variables:**

# %%
# list of numerical variables
numerical_features = [feature for feature in house_df.columns if house_df[feature].dtypes != 'O']

print('Number of numerical variables: ', len(numerical_features))

# visualise the numerical variables
house_df[numerical_features].head()
# Out:
# Number of numerical variables:  14
#    year_built  stories  num_bedrooms  full_bathrooms  half_bathrooms  \
# 0        1978        1             4               1               1
# 1        1958        1             3               1               1
# 2        2002        1             3               2               0
# 3        2004        1             4               2               0
# 4        2006        1             4               2               0
#
#    livable_sqft  total_sqft  garage_sqft  carport_sqft  has_fireplace  \
# 0          1689        1859          508             0           True
# 1          1984        2002          462             0           True
# 2          1581        1578            0           625          False
# 3          1829        2277          479             0           True
# 4          1580        1749          430             0           True
#
#    has_pool  has_central_heating  has_central_cooling  sale_price
# 0     False                 True                 True    270897.0
# 1     False                 True                 True    302404.0
# 2     False                 True                 True   2519996.0
# 3     False                 True                 True    197193.0
# 4     False                 True                 True    207897.0

# %% [markdown]
# Numerical variables are usually of 2 types: Continous variables and Discrete Variables
#
# Discrete Variable: a variable whose value is obtained by counting.
#
# Continuous Variable: a variable which can take an uncountable set of values or infinite set of values.

# %% [markdown]
# ***Discrete Variables:***

# %%
discrete_feature=[feature for feature in numerical_features if len(house_df[feature].unique())<25]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
discrete_feature
# Out:
# Discrete Variables Count: 8
# ['stories',
#  'num_bedrooms',
#  'full_bathrooms',
#  'half_bathrooms',
#  'has_fireplace',
#  'has_pool',
#  'has_central_heating',
#  'has_central_cooling']

# %%
# Lets Find the realtionship between them and Sale Price

for feature in discrete_feature:
    data=house_df.copy()
    data.groupby(feature)['sale_price'].median().plot.bar(color='mediumseagreen')
    plt.xlabel(feature)
    plt.ylabel('sale_price')
    plt.title(feature)
    plt.show()

# %% [markdown]
# ***Continuous Variables:***

# %%
continuous_feature=[feature for feature in numerical_features if feature not in discrete_feature]
print("Continuous feature Count {}".format(len(continuous_feature)))
continuous_feature
# Out:
# Continuous feature Count 6
# ['year_built',
#  'livable_sqft',
#  'total_sqft',
#  'garage_sqft',
#  'carport_sqft',
#  'sale_price']

# %%
# Lets analyse the continuous values by creating histograms to understand the distribution

for feature in continuous_feature:
    data=house_df.copy()
    data[feature].hist(bins=25, color='mediumseagreen')
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
for feature in continuous_feature:
    data=house_df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data["sale_price"]=np.log(data["sale_price"])
        plt.scatter(data[feature],data["sale_price"],color='mediumseagreen')
        plt.xlabel(feature)
        plt.ylabel('SalesPrice')
        plt.title(feature)
        plt.show()
# Out:
# C:\Users\dtaher\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#I will do a histogram of the year built separately 
house_df['year_built'].hist(bins = 100, color = 'mediumseagreen')
plt.xlabel('Year Built')
plt.ylabel('count')
plt.show()

# %% [markdown]
# **Categorical Variables**:
#
# I will use one-hot encoding to the columns with categorical values in order to use it in my model: the garage_type and city. One-Hot Encoding is the process of creating dummy variables for categorical variables. For every categorical feature, a new numerical variable is created.

# %%
categorical_features=[feature for feature in house_df.columns if data[feature].dtypes=='O']
print(categorical_features)

for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature,len(house_df[feature].unique())))
# Out:
# ['garage_type', 'city']
# The feature is garage_type and number of categories are 3
# The feature is city and number of categories are 47

# %%
house_df['city'].value_counts()
# Out:
# Chadstad                4962
# Coletown                3739
# Jeffreyhaven            2981
# North Erinville         2868
# Port Andrealand         2669
# Hallfort                2448
# Lewishaven              2271
# South Anthony           1849
# Lake Jack               1831
# Davidfort               1703
# Lake Dariusborough      1441
# West Ann                1397
# East Lucas              1359
# Port Jonathanborough    1344
# Scottberg               1009
# Lake Christinaport       833
# East Amychester          792
# Joshuafurt               745
# West Lydia               709
# Morrisport               654
# Lake Carolyn             637
# West Gregoryview         615
# Wendybury                587
# Amystad                  561
# Port Adamtown            416
# Richardport              297
# Jenniferberg             275
# Justinport               272
# East Janiceville         248
# Brownport                209
# Clarkberg                174
# West Gerald              151
# West Brittanyview        120
# East Justin              112
# West Terrence            107
# Lake Jennifer             83
# South Stevenfurt          53
# Port Daniel               52
# Leahview                  27
# Toddshire                 27
# Fosterberg                26
# Davidtown                 18
# Rickytown                 14
# Martinezfort               9
# Julieberg                  6
# New Michele                2
# New Robinton               1
# Name: city, dtype: int64

# %%
house_df['garage_type'].value_counts()
# Out:
# attached    34079
# none         5912
# detached     2712
# Name: garage_type, dtype: int64

# %%
for feature in categorical_features:
    data=house_df.copy()
    data.groupby(feature)["sale_price"].median().plot.bar(color='mediumseagreen')
    plt.xlabel(feature)
    plt.ylabel("sale_price")
    plt.title(feature)
    plt.show()

# %%
# A clearer plot than the one above
fig, ax = plt.subplots(figsize=(17,7))
house_df.groupby("city").median().plot.bar(y="sale_price", ax=ax, color='mediumseagreen');
# format the y label 1e6
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

plt.xticks(rotation=60)
plt.title('House Sale Prices by City', fontsize=16)
plt.ylabel('House Prices in USD')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dtaher\AppData\Local\Temp\ipykernel_15056\906618370.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# %% [markdown]
# **One-hot encoding of categorical variables**
#
# I will now do one-hot encoding to the categorical variables so I can use it in my model

# %%
# Replace categorical data with one-hot encoded data
features_df = pd.get_dummies(house_df, columns=['garage_type', 'city'])
features_df
# Out:
#        year_built  stories  num_bedrooms  full_bathrooms  half_bathrooms  \
# 0            1978        1             4               1               1
# 1            1958        1             3               1               1
# 2            2002        1             3               2               0
# 3            2004        1             4               2               0
# 4            2006        1             4               2               0
# ...           ...      ...           ...             ...             ...
# 42698        1982        1             1               1               0
# 42699        1983        1             1               1               0
# 42700        1983        1             1               1               0
# 42701        1981        1             3               2               0
# 42702        1980        1             3               2               0
#
#        livable_sqft  total_sqft  garage_sqft  carport_sqft  has_fireplace  \
# 0              1689        1859          508             0           True
# 1              1984        2002          462             0           True
# 2              1581        1578            0           625          False
# 3              1829        2277          479             0           True
# 4              1580        1749          430             0           True
# ...             ...         ...          ...           ...            ...
# 42698           591         627            0           200          False
# 42699           592         624            0           204          False
# 42700           594         618            0           197          False
# 42701          1398        1401          401             0          False
# 42702          1401        1406          396             0          False
#
#        ...  city_South Anthony  city_South Stevenfurt  city_Toddshire  \
# 0      ...                   0                      0               0
# 1      ...                   0                      0               0
# 2      ...                   0                      0               0
# 3      ...                   0                      0               0
# 4      ...                   0                      0               0
# ...    ...                 ...                    ...             ...
# 42698  ...                   0                      0               0
# 42699  ...                   0                      0               0
# 42700  ...                   0                      0               0
# 42701  ...                   0                      0               0
# 42702  ...                   0                      0               0
#
#        city_Wendybury  city_West Ann  city_West Brittanyview  \
# 0                   0              0                       0
# 1                   0              0                       0
# 2                   0              0                       0
# 3                   0              0                       0
# 4                   0              0                       0
# ...               ...            ...                     ...
# 42698               0              0                       0
# 42699               0              0                       0
# 42700               0              0                       0
# 42701               0              0                       0
# 42702               0              0                       0
#
#        city_West Gerald  city_West Gregoryview  city_West Lydia  \
# 0                     0                      0                0
# 1                     0                      0                0
# 2                     0                      0                0
# 3                     0                      0                0
# 4                     0                      0                0
# ...                 ...                    ...              ...
# 42698                 0                      0                0
# 42699                 0                      0                0
# 42700                 0                      0                0
# 42701                 0                      0                0
# 42702                 0                      0                0
#
#        city_West Terrence
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 42698                   0
# 42699                   0
# 42700                   0
# 42701                   0
# 42702                   0
#
# [42703 rows x 64 columns]

# %% [markdown]
# The target variable that I'm trying to predict is the house's sale price. the different features in my data set will be utilized as the predictors of the target variable.
#
# Therefore, I will need to separate the sale price column from the features data frame so the ML model doesn't see the sale price in the input data.

# %%
# Remove the sale price from the feature data
features_df.drop(['sale_price'], axis = 1, inplace=True)

# %% [markdown]
# **X and y Lists**
#
# I will create X and y arrays.
#
# X to represent the input features (house features, indepedent variables)
#
# y to represent the expected output to predict (house sale price, dependent variable)

# %%
# the X array will be the contents of my features dataframe.
X = features_df

# the y array will be the sales price column from my original dataset
y = house_df['sale_price']

# %% [markdown]
# **Train & Test Data**
#
# In this section, I will perform a train-test-split. When performing a train-test-split, it is important that the data is randomly split. Another thing to consider is just how big each training and testing set should be. I split the data into a training data set and a test data set. I will use Scikit-learn to do this in one linne of code. I will do the training set size at 70% and 30% for the testing set.
#
# By training and testing, it will allow us to prove the accuracy of the model and prove that it actually learned general rules for predicting house prices.

# %%
#This command will shuffle all of our data so it's in a random order, and then split it into two groups. 
#The test size equals 0.3 parameter tells it we want to keep 70% of the data for training and 30%for testing. 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
#viewing the lengths of the data
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 29892 12811 29892 12811

# %% [markdown]
# # Modeling
#
# In the following section, I will be creating a baseline model which will be a linear regression. This model will then be used for comparison with another model (random forest).
# A final model will also be created using XGBOOST, I will be comparing the previous 2 models to it as well.
#
# This will allow me to choose the best and most accurate model based on the results each model provides.

# %% [markdown]
# ## Creating, Training, and Evaluating the LinearRegression Model

# %% [markdown]
# For this machine learning model, I will be using a Linear Regression model.
#
# I will import and create sklearn linearmodel LinearRegression object and fit the training dataset in it.

# %%
# Create a Linear regressor
lm = LinearRegression()
# Train the model using the training sets 
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Linear Regression: Model prediction on train data**
#
# I will look at the model prediction using the training data (X_train)

# %%
# Model prediction on train data
y_pred = lm.predict(X_train)

# %% [markdown]
# **Model Evaluation**

# %% [markdown]
# 𝑅^2 : is a measure of the linear relationship between X and Y. It is interpreted as the proportion of the variance in the dependent variable that is predictable from the independent variable. it's a range between 0 and 1 where 1 perfectly fits the data.
#
# Adjusted 𝑅^2 :The adjusted R-squared compares the explanatory power of regression models that contain different numbers of predictors.
#
# MAE : It is the mean of the absolute value of the errors. It measures the difference between two continuous variables, here actual and predicted values of y.
#
# MSE: The mean square error (MSE) is just like the MAE, but squares the difference before summing them all instead of using the absolute value.
#
# RMSE: The mean square error (MSE) is just like the MAE, but squares the difference before summing them all instead of using the absolute value.

# %%
# Model Evaluation
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# R^2: 0.5290328406077318
# Adjusted R^2: 0.5280381064303913
# MAE: 96626.75957422446
# MSE: 51595807085.88413
# RMSE: 227147.1045069343

# %% [markdown]
# The R2  is 0.53, This means that our model is explaining about 53% of the variance in house sale prices. The adjusted R2 has been adjusted for the number of predictors in the model but we can see here that they're both about the same.
#
# The MAE value is telling us that our model is off by about 96,626 USD in a given prediction.
#
# The RMSE value is telling us that our model is off by about 227,147 USD in a given prediction.

# %% [markdown]
# I want to visualize the differences between actual prices and predicted values

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train, y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %% [markdown]
# What we're getting is sort of a non-linear model

# %% [markdown]
# I want to check the residuals in my model, the residuals is the level of error in regression model, which is difference between the actual value of y and predicted value of y (regression line).

# %%
# Checking residuals
plt.scatter(y_pred,y_train-y_pred)
plt.title("Predicted vs residuals")
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# The error here is substantial

# %%
# Checking Normality of errors
plt.figure(figsize = (12,8))
sns.distplot(y_train-y_pred)
plt.title("Histogram of Residuals")
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\dtaher\AppData\Local\Temp\ipykernel_15056\3140813144.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train-y_pred)

# %% [markdown]
# it looks close to anormal distribution with a mean of 0, there is right skew which what we're observing on the scatter plot above, we're observing some outliers.

# %% [markdown]
# **Test Data Evaluation**

# %% [markdown]
# We will now predict and evaluate the testing data

# %%
# Predicting Test data with the model
y_test_pred = lm.predict(X_test)

# %%
# Model Evaluation
acc_linreg = metrics.r2_score(y_test, y_test_pred)
adj_R2_linreg = 1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
mae_linreg = metrics.mean_absolute_error(y_test, y_test_pred)
mse_linreg = metrics.mean_squared_error(y_test, y_test_pred)
rmse_linreg = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))
print('R^2:', acc_linreg)
print('Adjusted R^2:',adj_R2_linreg)
print('MAE:',mae_linreg)
print('MSE:',mse_linreg)
print('RMSE:',rmse_linreg)
# Out:
# R^2: 0.6680874541045617
# Adjusted R^2: 0.666447029660268
# MAE: 95834.33597828115
# MSE: 27418898422.417503
# RMSE: 165586.52850524255

# %% [markdown]
# The error values are better on the test data than our training data.
#
# With the test data the R2 increased by about 12%, This means that our model is explaining about 66% of the variance in house sale prices.
#
# The MAE value is slightly better here, its telling us that our model is off by about 95,834 USD in a given prediction.
#
# The RMSE value is significantly less than our training data, its telling us that our model is off by about 165,586 USD in a given prediction.

# %% [markdown]
# ## Creating, Training, and Evaluating the Random Forest Model

# %% [markdown]
# The Linear Regression model that we built will be used as our baseline model. I will now create a random forest regressor and will eventually compare it with our previous model so that we pick the one with the best results.

# %%
# Create a Random Forest Regressor
reg = RandomForestRegressor()

# Train the model using the training sets 
reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# **Random Forest: Model prediction and evaluation on train data**
#
# I will look at the model prediction using the training data (X_train)

# %%
# Model prediction on train data
y_pred = reg.predict(X_train)

# %%
# Model Evaluation
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# R^2: 0.9403284002925949
# Adjusted R^2: 0.9402023673443058
# MAE: 23380.57220198922
# MSE: 6537195398.044817
# RMSE: 80852.92448665551

# %% [markdown]
# The Random Forest got better results than the linear regression model.
#
# R2 is at 94% which is a significant difference than the previous model.
#
# MAE and RMSE have also significantly decreased which is so much better in our case. Now the MAE is telling us that our model is off by about 23,380 USD in a given prediction, and the RMSE is off by 80,852 USD in a given prediction.

# %% [markdown]
# I want to visualize the differences between actual prices and predicted values

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train, y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %% [markdown]
# Visually, Random Forest is doing better here as well. It is more linear and we don't observe as much error.

# %%
# Checking residuals
plt.scatter(y_pred,y_train-y_pred)
plt.title("Predicted vs residuals")
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# In terms of residuals, we are observing less error, the maximum value here is about 7 million while for the linear regression the maximum was about 20 million.
#
# Random Forest is doing better here as well.

# %% [markdown]
# **Test Data Prediction and Evaluation**
#
# We will now predict and evaluate the testing data

# %%
# Predicting Test data with the model
y_test_pred = reg.predict(X_test)

# %%
# Model Evaluation
acc_rf = metrics.r2_score(y_test, y_test_pred)
adj_R2_rf = 1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
mae_rf = metrics.mean_absolute_error(y_test, y_test_pred)
mse_rf = metrics.mean_squared_error(y_test, y_test_pred)
rmse_rf = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))
print('R^2:', acc_rf)
print('Adjusted R^2:',adj_R2_rf)
print('MAE:',mae_rf)
print('MSE:',mse_rf)
print('RMSE:',rmse_rf)
# Out:
# R^2: 0.7912345427515018
# Adjusted R^2: 0.7902027530122177
# MAE: 58965.07385961506
# MSE: 17245864723.080917
# RMSE: 131323.51169185553

# %% [markdown]
# The test data R2 went down by about 15% which tends to say that it's not robust but it is still performing very well at 79% which is still higher than the linear regression model.
#
# MAE and RMSE have increased compared to the train data.
# Now the MAE is telling us that our model is off by about 58,965 USD in a given prediction, and the RMSE is off by 131,323 USD in a given prediction.
#
#
# but in general the Random forest testing data metrics are still performing better than the testing data in the linear regression model.

# %% [markdown]
# ## Creating, Training, and Evaluating the XGBOOST  Model

# %% [markdown]
# This is the final model I will be running and after I will be able to determiine which model out of the three performed the best.

# %%
#Create a XGBoost Regressor
reg = XGBRegressor()

# Train the model using the training sets 
reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# **Model prediction and evaluation on train data**

# %%
# Model prediction on train data
y_pred = reg.predict(X_train)

# %%
# Model Evaluation
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# R^2: 0.9385055307668579
# Adjusted R^2: 0.9383756477186587
# MAE: 49872.13058101002
# MSE: 6736895998.218352
# RMSE: 82078.59646837506

# %% [markdown]
# This model is performing much better than the 2 previous ones.
#
# The R2 is 0.93, This means that our model is explaining about 93% of the variance in house sale prices. The adjusted R2 is about the same.
#
# The MAE value is telling us that our model is off by about 49,872 USD in a given prediction.
#
# The RMSE value is telling us that our model is off by about 82,078 USD in a given prediction.

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train, y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
# Checking residuals
plt.scatter(y_pred,y_train-y_pred)
plt.title("Predicted vs residuals")
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# **Test Data Prediction and Evaluation**
#
# We will now predict and evaluate the testing data

# %%
#Predicting Test data with the model
y_test_pred = reg.predict(X_test)

# %%
# Model Evaluation
acc_xgb = metrics.r2_score(y_test, y_test_pred)
adj_R2_xgb = 1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
mae_xgb = metrics.mean_absolute_error(y_test, y_test_pred)
mse_xgb = metrics.mean_squared_error(y_test, y_test_pred)
rmse_xgb = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))
print('R^2:', acc_xgb)
print('Adjusted R^2:',adj_R2_xgb)
print('MAE:',mae_xgb)
print('MSE:',mse_xgb)
print('RMSE:',rmse_xgb)
# Out:
# R^2: 0.76261227397481
# Adjusted R^2: 0.7614390232695785
# MAE: 63694.1479818489
# MSE: 19610316112.19616
# RMSE: 140036.8384111701

# %% [markdown]
# Finally, the R2 decreased on the testing data compared to the training data.
# XGBoost R2 is at 76%, which means that our model is explaining about 76% of the variance in house sale prices. The adjusted R2 is about the same.
#
# The Random Forest model had the best R2 score out of the 3 models.
#
# The MAE value is telling us that our model is off by about 63,694 USD in a given prediction.
#
# The RMSE value is telling us that our model is off by about 140,036 USD in a given prediction.

# %% [markdown]
# ## Comparing the final three models

# %%
models = pd.DataFrame({
    'Model': ['Linear Regression', 'Random Forest', 'XGBoost'],
    'R-squared Score': [acc_linreg*100, acc_rf*100, acc_xgb*100],
    'Adjusted R-squared Score': [adj_R2_linreg*100, adj_R2_rf*100, adj_R2_xgb*100],
    'MAE': [mae_linreg, mae_rf, mae_xgb],
    'MSE': [mse_linreg, mse_rf, mse_xgb],
    'RMSE': [rmse_linreg, rmse_rf, rmse_xgb]})
models.sort_values(by='R-squared Score', ascending=False)
# Out:
#                Model  R-squared Score  Adjusted R-squared Score           MAE  \
# 1      Random Forest        79.123454                 79.020275  58965.073860
# 2            XGBoost        76.261227                 76.143902  63694.147982
# 0  Linear Regression        66.808745                 66.644703  95834.335978
#
#             MSE           RMSE
# 1  1.724586e+10  131323.511692
# 2  1.961032e+10  140036.838411
# 0  2.741890e+10  165586.528505

# %% [markdown]
# When we put all the modes together and compare we can see that the Random Forest Model has the best accuracy results in all the metrics.
#
# Therefore, the random forest model is the most accurate model that will help predict house sale prices most accurately.
